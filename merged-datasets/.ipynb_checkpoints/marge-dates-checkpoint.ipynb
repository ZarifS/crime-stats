# %%
import pandas as pd 
denver_data = pd.read_csv("../denver-datasets/denver-date.csv") 
vancouver_data = pd.read_csv("../vancouver-datasets/vancouver-date.csv")

# %%
denver_data.head(5)
# Out:
#                                date_key  year  month  day day_of_week  \
# 0  7b204d79-97d8-4eeb-8815-a64082e5f4f1  2016      6   15   Wednesday
# 1  8ae8bcc1-3af4-46cc-9d4e-c0bce6496a22  2017     10   11   Wednesday
# 2  6a0a1ef3-1ed6-4ef5-abad-2e4466ae33f1  2016      3    4      Friday
# 3  9fcc7225-793e-4dc8-9717-737149233431  2018      1   30     Tuesday
# 4  25df993f-fe14-409a-bdb2-eb2f353a9f45  2017      6   22    Thursday
#
#    is_weekend  is_holiday holiday_name
# 0       False       False          NaN
# 1       False       False          NaN
# 2       False       False          NaN
# 3       False       False          NaN
# 4       False       False          NaN

# %%
vancouver_data.head(5)
# Out:
#                                date_key  year  month  day day_of_week  \
# 0  f662d2a2-dd73-4f57-a64e-756b4ba12220  2012     12   14      Friday
# 1  aa72acce-38b2-4616-9536-686a766ebf9a  2019      3    7    Thursday
# 2  61c4d012-7df2-4601-ba84-316e98625199  2019      8   27     Tuesday
# 3  0b1bcd0c-3810-4820-8b01-7995f10c54bb  2014      8    8      Friday
# 4  0d305dd0-6b0c-4d4b-927a-f8e07c759cf7  2005     11   14      Monday
#
#    is_weekend  is_holiday holiday_name
# 0       False       False          NaN
# 1       False       False          NaN
# 2       False       False          NaN
# 3       False       False          NaN
# 4       False       False          NaN

# %%
denver_data = denver_data.rename(columns={"is_holiday": "is_american_holiday", "holiday_name": "american_holiday_name"}, errors="raise")
denver_data.head(5)
# Out:
#                                date_key  year  month  day day_of_week  \
# 0  7b204d79-97d8-4eeb-8815-a64082e5f4f1  2016      6   15   Wednesday
# 1  8ae8bcc1-3af4-46cc-9d4e-c0bce6496a22  2017     10   11   Wednesday
# 2  6a0a1ef3-1ed6-4ef5-abad-2e4466ae33f1  2016      3    4      Friday
# 3  9fcc7225-793e-4dc8-9717-737149233431  2018      1   30     Tuesday
# 4  25df993f-fe14-409a-bdb2-eb2f353a9f45  2017      6   22    Thursday
#
#    is_weekend  is_american_holiday american_holiday_name
# 0       False                False                   NaN
# 1       False                False                   NaN
# 2       False                False                   NaN
# 3       False                False                   NaN
# 4       False                False                   NaN

# %%
vancouver_data = vancouver_data.rename(columns={"is_holiday": "is_canadian_holiday", "holiday_name": "canadian_holiday_name"}, errors="raise")
vancouver_data.head()
# Out:
#                                date_key  year  month  day day_of_week  \
# 0  f662d2a2-dd73-4f57-a64e-756b4ba12220  2012     12   14      Friday
# 1  aa72acce-38b2-4616-9536-686a766ebf9a  2019      3    7    Thursday
# 2  61c4d012-7df2-4601-ba84-316e98625199  2019      8   27     Tuesday
# 3  0b1bcd0c-3810-4820-8b01-7995f10c54bb  2014      8    8      Friday
# 4  0d305dd0-6b0c-4d4b-927a-f8e07c759cf7  2005     11   14      Monday
#
#    is_weekend  is_canadian_holiday canadian_holiday_name
# 0       False                False                   NaN
# 1       False                False                   NaN
# 2       False                False                   NaN
# 3       False                False                   NaN
# 4       False                False                   NaN

# %%
# This merges the two datasets together
result = pd.merge(denver_data, vancouver_data, on=['year', 'month', 'day', 'day_of_week', 'is_weekend'])
result = result.drop(['date_key_x', 'date_key_y'], axis=1)
result.head()
# Out:
#    year  month  day day_of_week  is_weekend  is_american_holiday  \
# 0  2016      6   15   Wednesday       False                False
# 1  2016      6   15   Wednesday       False                False
# 2  2016      6   15   Wednesday       False                False
# 3  2016      6   15   Wednesday       False                False
# 4  2016      6   15   Wednesday       False                False
#
#   american_holiday_name  is_canadian_holiday canadian_holiday_name
# 0                   NaN                False                   NaN
# 1                   NaN                False                   NaN
# 2                   NaN                False                   NaN
# 3                   NaN                False                   NaN
# 4                   NaN                False                   NaN

# %%
#add date_key
import uuid
date_keys = []
for i in range(result.shape[0]):
    id = uuid.uuid4() 
    date_keys.append(id)

result['date_key'] = date_keys

result.head()
# Out:
#    year  month  day day_of_week  is_weekend  is_american_holiday  \
# 0  2016      6   15   Wednesday       False                False
# 1  2016      6   15   Wednesday       False                False
# 2  2016      6   15   Wednesday       False                False
# 3  2016      6   15   Wednesday       False                False
# 4  2016      6   15   Wednesday       False                False
#
#   american_holiday_name  is_canadian_holiday canadian_holiday_name  \
# 0                   NaN                False                   NaN
# 1                   NaN                False                   NaN
# 2                   NaN                False                   NaN
# 3                   NaN                False                   NaN
# 4                   NaN                False                   NaN
#
#                                date_key
# 0  dd30cdbb-dd8a-4dc6-80e3-ba07407a4ff7
# 1  c7763481-1b4a-4a77-9c0d-9578e11583a7
# 2  2007c092-1dc7-426a-b523-c46931e07af6
# 3  ad5d99db-2c63-423a-9e3f-6c1d2b161d50
# 4  a45da364-b3bf-462c-a403-be02303d11ff

# %%
# Shift date_key to the first column
cols = result.columns.tolist()
newcols = [cols[9]] + cols[0:9]
result = result[newcols]
print(cols)
# Out:
# ['year', 'month', 'day', 'day_of_week', 'is_weekend', 'is_american_holiday', 'american_holiday_name', 'is_canadian_holiday', 'canadian_holiday_name', 'date_key']

# %%
result.head()
# Out:
#                                date_key  year  month  day day_of_week  \
# 0  60ffeb8f-32b3-457a-b076-f38ff3bfc1fc  2016      6   15   Wednesday
# 1  3c12a434-b09c-42be-8d45-6809d1d9efa7  2016      6   15   Wednesday
# 2  e2c97bf0-cead-41c3-a8be-be750d4cb9d9  2016      6   15   Wednesday
# 3  71cbce1e-b746-4f02-9d1b-e3fd28ec0973  2016      6   15   Wednesday
# 4  a7ec728f-97dd-4bcd-b049-127c913ecc44  2016      6   15   Wednesday
#
#    is_weekend  is_american_holiday american_holiday_name  is_canadian_holiday  \
# 0       False                False                   NaN                False
# 1       False                False                   NaN                False
# 2       False                False                   NaN                False
# 3       False                False                   NaN                False
# 4       False                False                   NaN                False
#
#   canadian_holiday_name
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
print('Total number of rows with duplicates:', result.shape[0])
# Out:
# Total number of rows with duplicates: 193286

# %%
result.drop_duplicates(subset=["year", "month","day"], inplace=True)
result.head()
# Out:
#                                  date_key  year  month  day day_of_week  \
# 0    dd30cdbb-dd8a-4dc6-80e3-ba07407a4ff7  2016      6   15   Wednesday
# 114  30cfd6cd-2f56-4da2-920e-09cc958fe766  2017     10   11   Wednesday
# 217  c4f2a260-7bc4-4ba4-8961-240e13db85ae  2016      3    4      Friday
# 345  10e79260-6164-4ac2-94c9-8dba650b1abd  2018      1   30     Tuesday
# 433  c0a01024-1be7-4763-ad42-a6bd4737268f  2017      6   22    Thursday
#
#      is_weekend  is_american_holiday american_holiday_name  \
# 0         False                False                   NaN
# 114       False                False                   NaN
# 217       False                False                   NaN
# 345       False                False                   NaN
# 433       False                False                   NaN
#
#      is_canadian_holiday canadian_holiday_name
# 0                  False                   NaN
# 114                False                   NaN
# 217                False                   NaN
# 345                False                   NaN
# 433                False                   NaN

# %%
print('Total number of rows without duplicates:', result.shape[0])
# Out:
# Total number of rows without duplicates: 1870

# %%
# Transfer data to csv file
result.to_csv(r'./merged-dates.csv', index = None, header=True)
