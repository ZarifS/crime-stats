# %%
import pandas as pd
denver_parent_data = pd.read_csv("../datasets/denver-data.csv")

# %%
print(denver_parent_data.shape[0])
# Out:
# 466840

# %%
denver_address = pd.read_csv("./denver-address.csv")
print(denver_address.shape[0])
denver_crime = pd.read_csv("./denver-crime.csv")
print(denver_crime.shape[0])
denver_date = pd.read_csv("./denver-date.csv")
print(denver_date.shape[0])
# Out:
# 92432
# 466840
# 1870

# %%
denver_address.head()
# Out:
#                            location_key          location_name  \
# 0  dcd36c09-2095-4935-bac2-62bb9ba8738e                    NaN
# 1  beb00ff6-50f9-47d4-b6ce-fccced9416df    2932 S JOSEPHINE ST
# 2  94bb4127-7768-4ac9-bac2-9bf22d883ea4    705 S COLORADO BLVD
# 3  63c820a1-a440-47ba-a3b9-c6005182d47a         2810 E 1ST AVE
# 4  22a9e68a-1afd-4f22-ad22-9a499647ce48  2100 BLOCK E 17TH AVE
#
#      neighborhood    city   longitude   latitude
# 0       montbello  Denver -104.809881  39.773188
# 1       wellshire  Denver -104.957381  39.663490
# 2         belcaro  Denver -104.941440  39.702698
# 3    cherry-creek  Denver -104.955370  39.717107
# 4  city-park-west  Denver -104.961928  39.743149

# %%
#Adding Denver crime-key
denver_parent_data = pd.concat([denver_parent_data, denver_crime], axis=1)
denver_parent_data.head()
# Out:
#     INCIDENT_ID    OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0  2.016377e+09  2.016380e+15          5213                       0
# 1  2.018600e+10  2.018600e+16          2399                       0
# 2  2.016600e+10  2.016600e+16          2305                       0
# 3  2.018723e+08  2.018720e+14          2399                       0
# 4  2.017411e+09  2.017410e+15          2303                       0
#
#                 OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0  weapon-unlawful-discharge-of          all-other-crimes
# 1                   theft-other                   larceny
# 2      theft-items-from-vehicle  theft-from-motor-vehicle
# 3                   theft-other                   larceny
# 4                theft-shoplift                   larceny
#
#     FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# 0   6/15/2016 11:31:00 PM                    NaN  6/15/2016 11:31:00 PM
# ...

# %%
#Adding Denver address-key
denver_parent_data = pd.merge(denver_parent_data, denver_address, how='left', left_on=['YEAR','MONTH', 'DAY'], right_on = ['year','month', 'day'])
